# %% [markdown]
# ## SQL to get data between 2001 and 2016

# %%
# -- select count(DISTINCT obs.PATIENT_NUM),count(obs.PATIENT_NUM)  
# --select *
# select obs.PATIENT_NUM, obs.CONCEPT_CD,obs.START_DATE, obs.VALTYPE_CD, obs.TVAL_CHAR, obs.NVAL_NUM, con.CONCEPT_PATH, con.NAME_CHAR, pat.SEX_CD, pat.LANGUAGE_CD,pat.RACE_CD,pat.ZIP_CD
# --obs.PATIENT_NUM, con.Concept_cd
# from 
# NSF_Algorithms.dbo.observation_fact obs, NSF_Algorithms.dbo.concept_dimension con, NSF_Algorithms.dbo.patient_dimension pat
# where	
# 	obs.PATIENT_NUM in
# 		(select PATIENT_NUM from NSF_Algorithms.dbo.observation_fact
# 		where 
# 		--CONCEPT_CD like '%HDID:50588%'
# 		CONCEPT_CD like '%RXCUI:688242%'
# 		)
# 	AND
# 		obs.CONCEPT_CD=con.CONCEPT_CD
# 	AND
# 		obs.PATIENT_NUM=pat.PATIENT_NUM
# 	AND
# 		(
# 		--con.CONCEPT_PATH like '%Testosterone%' 
# 		--OR
# 		----con.CONCEPT_PATH like '%Anti-Müllerian hormone%' 
# 		----OR
# 		con.CONCEPT_PATH like '%Luteinizing hormone%' 
# 		OR
# 		con.CONCEPT_PATH like '%Follicle Stimulating Hormone%' 
# 		OR
# 		con.CONCEPT_PATH like '%Progesterone%' 
# 		OR
# 		con.CONCEPT_PATH like '%Estrogen%' 
# 		OR		
# 		con.CONCEPT_PATH like '%fertility%' 
# 		OR
# 		con.CONCEPT_PATH like '%Family Planning%' 
# 		OR
# 		obs.CONCEPT_CD like '%HDID:50588%'
# 		--OR
# 		--con.CONCEPT_PATH like '%pregnancy%'
# 		)
# 	AND
# 		YEAR(obs.START_DATE) between 2001 and 2016
# --	--AND
# --	--	con.CONCEPT_PATH like '%pregnancy%'
# --	AND
# --		con.CONCEPT_PATH NOT LIKE '%Diseases of male genital organs%' 
# --	AND
# --		con.CONCEPT_PATH NOT LIKE '%male infertility%'	
# --		--obs.TVAL_CHAR != 'Male infertility, unspecified' 
# 	AND
# 		pat.SEX_CD='F'
		
# --		--obs.PATIENT_NUM like '9322698'
# ORDER BY obs.PATIENT_NUM	

# ----INTO OUTFILE 'data2001_2016.csv'
# ----FIELDS TERMINATED BY ','
# ----ENCLOSED BY '"'
# --LINES TERMINATED BY '\n'		
		
# ----	where Concept_cd like 'ICD9:250' 
# --    where Concept_cd in (
# --    select Concept_cd from NSF_Algorithms.dbo.concept_dimension
# --    where CONCEPT_PATH like'%Genetics/fertility\Bloom lab test%')
# --	and YEAR(Start_Date) between 2007 and 2012)
# --and Concept_cd in (
# --	select Concept_cd from NSF_Algorithms.dbo.concept_dimension
# --	where CONCEPT_PATH like '%Drug Products by VA class%')
# --and YEAR(Start_Date) between 2001 and 2012

# %% [markdown]
# # explore related features about hormone (related with fertility and Family Planning)

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## how many observations?

# %%
#df=pd.read_csv('data2001_2016.csv',nrows =10)
#df=pd.read_excel('data2001_2016.xlsx')
#hormone2001_2016
#df=pd.read_excel('FEMALE.xlsx')#pd.read_csv('FEMALE.csv')
df=pd.read_excel('RXCUI688242.xlsx')

# %%
df.head()
# Out:
#    PATIENT_NUM    CONCEPT_CD          START_DATE VALTYPE_CD  \
# 0         1547  RXCUI:688242 2013-05-08 14:48:56        NaN
# 1         1547  RXCUI:688242 2013-05-08 14:48:56        NaN
# 2         5054  RXCUI:688242 2009-02-01 13:32:04        NaN
# 3         5054  RXCUI:688242 2009-02-01 13:32:04        NaN
# 4         7406      HDID:149 2010-09-14 17:00:00          N
#
#                                            TVAL_CHAR  NVAL_NUM  \
# 0  1/2 applicatorful per vagina 3 times weekly (m...       NaN
# 1  1/2 applicatorful per vagina 3 times weekly (m...       NaN
# 2  intravaginally 1 gram daily x 4 wks the 2 gram...       NaN
# 3  intravaginally 1 gram daily x 4 wks the 2 gram...       NaN
# 4                                                  E       8.3
#
#                                         CONCEPT_PATH  \
# 0  \Drug Products by VA Class\GU000 GENITOURINARY...
# 1  \Drug Products by VA Class\GU000 GENITOURINARY...
# 2  \Drug Products by VA Class\GU000 GENITOURINARY...
# 3  \Drug Products by VA Class\GU000 GENITOURINARY...
# 4  \HDID2\Basic\Dx\Lab\Chemistry\follicle stimula...
#
#                                            NAME_CHAR SEX_CD  \
# 0  Estrogens, Conjugated (USP) 0.625 MG/ML Vagina...      F
# 1  Estrogens, Conjugated (USP) 0.625 MG/ML Vagina...      F
# 2  Estrogens, Conjugated (USP) 0.625 MG/ML Vagina...      F
# 3  Estrogens, Conjugated (USP) 0.625 MG/ML Vagina...      F
# 4     follicle stimulating hormone, serum (HDID:149)      F
#
#          LANGUAGE_CD            RACE_CD ZIP_CD
# 0   DEM|LANGUAGE:por  DEM|RACE:hispanic   2122
# 1   DEM|LANGUAGE:por  DEM|RACE:hispanic   2122
# 2  DEM|LANGUAGE:engl     DEM|RACE:black   2368
# 3  DEM|LANGUAGE:engl     DEM|RACE:black   2368
# 4  DEM|LANGUAGE:engl     DEM|RACE:black   2122

# %%
print(df.shape)
df.describe(include='all')
#fertility2001_2016_summary=data.describe(include='all')
#fertility2001_2016_summary.to_csv('fertility2001_2016_summary.csv')
# Out:
# (13428, 12)
#          PATIENT_NUM    CONCEPT_CD           START_DATE VALTYPE_CD  \
# count   1.342800e+04         13428                13428       2017
# unique           NaN            75                 6923          2
# top              NaN  RXCUI:688242  2002-10-20 19:37:29          N
# freq             NaN          8336                    8       1596
# first            NaN           NaN  2001-01-01 12:52:57        NaN
# last             NaN           NaN  2014-05-04 14:12:12        NaN
# mean    2.168096e+06           NaN                  NaN        NaN
# std     1.775961e+06           NaN                  NaN        NaN
# min     1.547000e+03           NaN                  NaN        NaN
# 25%     1.141509e+06           NaN                  NaN        NaN
# 50%     1.451184e+06           NaN                  NaN        NaN
# 75%     2.824752e+06           NaN                  NaN        NaN
# max     1.120139e+07           NaN                  NaN        NaN
#
#                                      TVAL_CHAR     NVAL_NUM  \
# count                                    13275  1596.000000
# unique                                    2336          NaN
# top     apply 1/2 applicator full twice a week          NaN
# freq                                      1599          NaN
# first                                      NaN          NaN
# last                                       NaN          NaN
# mean                                       NaN    30.926692
# std                                        NaN    28.996912
# min                                        NaN    -3.000000
# 25%                                        NaN     6.900000
# 50%                                        NaN    24.050000
# 75%                                        NaN    47.500000
# max                                        NaN   212.800000
#
#                                              CONCEPT_PATH  \
# count                                               13428
# unique                                                 81
# top     \Drug Products by VA Class\GU000 GENITOURINARY...
# freq                                                 8336
# first                                                 NaN
# last                                                  NaN
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                                 NAME_CHAR SEX_CD  \
# count                                               13428  13428
# unique                                                 88      1
# top     Estrogens, Conjugated (USP) 0.625 MG/ML Vagina...      F
# freq                                                 4168  13428
# first                                                 NaN    NaN
# last                                                  NaN    NaN
# mean                                                  NaN    NaN
# std                                                   NaN    NaN
# min                                                   NaN    NaN
# 25%                                                   NaN    NaN
# 50%                                                   NaN    NaN
# 75%                                                   NaN    NaN
# max                                                   NaN    NaN
#
#               LANGUAGE_CD         RACE_CD   ZIP_CD
# count               13428           13428  13428.0
# unique                 27              10    299.0
# top     DEM|LANGUAGE:engl  DEM|RACE:black   2124.0
# freq                 8479            4822    852.0
# first                 NaN             NaN      NaN
# last                  NaN             NaN      NaN
# mean                  NaN             NaN      NaN
# std                   NaN             NaN      NaN
# min                   NaN             NaN      NaN
# 25%                   NaN             NaN      NaN
# 50%                   NaN             NaN      NaN
# 75%                   NaN             NaN      NaN
# max                   NaN             NaN      NaN

# %% [markdown]
# ## how many distinct patients?

# %%
len(df.PATIENT_NUM.unique())
# Out:
# 2011

# %%
#df.NAME_CHAR.unique()

# %% [markdown]
# ## drop NAN columns

# %%
# df1=df.dropna(axis=1, how='all')
# #df1.head()

# #df1.describe(include='all')

# df1.INSTANCE_NUM.unique()

# %% [markdown]
# ## drop all 0 columns

# %%
# df2=df1.loc[:, (df1 != df1.ix[0]).any()] 

# fertility2001_2016_summary2=df2.describe(include='all')

# fertility2001_2016_summary2

# %%
#fertility2001_2016_summary2.to_csv('fertility2001_2016_summary2.csv')

# %% [markdown]
# # ignore above 2 cells

# %%
df2=df

# %% [markdown]
# ## 1 high freq feature

# %%
df2[df2.CONCEPT_CD=='HDID:149'].head(2)
# Out:
#    PATIENT_NUM CONCEPT_CD          START_DATE VALTYPE_CD TVAL_CHAR  NVAL_NUM  \
# 4         7406   HDID:149 2010-09-14 17:00:00          N         E       8.3
# 5         7406   HDID:149 2010-09-14 17:00:00          N         E       8.3
#
#                                         CONCEPT_PATH  \
# 4  \HDID2\Basic\Dx\Lab\Chemistry\follicle stimula...
# 5  \HDID\GE-F\follicle stimulating hormone, serum...
#
#                                         NAME_CHAR SEX_CD        LANGUAGE_CD  \
# 4  follicle stimulating hormone, serum (HDID:149)      F  DEM|LANGUAGE:engl
# 5  follicle stimulating hormone, serum (HDID:149)      F  DEM|LANGUAGE:engl
#
#           RACE_CD ZIP_CD
# 4  DEM|RACE:black   2122
# 5  DEM|RACE:black   2122

# %% [markdown]
# ## 1 high freq feature

# %%
# df2[df2.CONCEPT_CD=='HDID:39874'].TVAL_CHAR.value_counts()#.head()
df2[df2.CONCEPT_CD=='HDID:301'].head(2)
# Out:
#      PATIENT_NUM CONCEPT_CD          START_DATE VALTYPE_CD TVAL_CHAR  \
# 138       115164   HDID:301 2004-05-02 12:15:00          N         E
# 139       115164   HDID:301 2004-05-02 12:15:00          N         E
#
#      NVAL_NUM                                       CONCEPT_PATH  \
# 138      26.2  \HDID2\Basic\Dx\Lab\Chemistry\luteinizing horm...
# 139      26.2  \HDID\GE-L\luteinizing hormone, serum (HDID:301)\
#
#                                  NAME_CHAR SEX_CD        LANGUAGE_CD  \
# 138  luteinizing hormone, serum (HDID:301)      F  DEM|LANGUAGE:engl
# 139  luteinizing hormone, serum (HDID:301)      F  DEM|LANGUAGE:engl
#
#             RACE_CD ZIP_CD
# 138  DEM|RACE:black   2119
# 139  DEM|RACE:black   2119

# %% [markdown]
# ##  all high freq features by value_counts of column NAME_CHAR

# %%
df2_NAME_CHAR=df2.NAME_CHAR.value_counts()
df2_NAME_CHAR
# Out:
# Estrogens, Conjugated (USP) 0.625 MG/ML Vaginal Cream [Premarin] RXCUI:688242 (RXCUI:688242)       4168
# Estrogens, Conjugated (USP) 0.625 MG/ML Vaginal Cream (Premarin) (RXCUI:688242) (RXCUI:688242)     4168
# follicle stimulating hormone, serum (HDID:149)                                                     1002
# Estradiol 0.1 MG/ML Vaginal Cream [Estrace] RXCUI:890918 (RXCUI:890918)                             790
# luteinizing hormone, serum (HDID:301)                                                               528
# Estrogens, Conjugated (USP) 0.625 MG Oral Tablet (Premarin) (RXCUI:150840) (RXCUI:150840)           507
# Estrogens, Conjugated (USP) 0.625 MG Oral Tablet [Premarin] RXCUI:150840 (RXCUI:150840)             507
# infertility, hx of (HDID:7177)                                                                      248
# Estrogens, Conjugated (USP) 0.3 MG Oral Tablet (Premarin) (RXCUI:208513) (RXCUI:208513)             180
# Estrogens, Conjugated (USP) 0.3 MG Oral Tablet [Premarin] RXCUI:208513 (RXCUI:208513)               180
# 90 DAY Estradiol 0.000313 MG/HR Vaginal Ring (Estring) (RXCUI:848330) (RXCUI:848330)                172
# Estrogens, Conjugated (USP) 1.25 MG Oral Tablet [Premarin] RXCUI:202301 (RXCUI:202301)               56
# Estrogens, Conjugated (USP) 1.25 MG Oral Tablet (Premarin) (RXCUI:202301) (RXCUI:202301)             56
# Infertility, female, of unspecified origin                                                           56
# progesterone, serum (HDID:292)                                                                       48
# Estradiol 1 MG Oral Tablet (Estrace) (RXCUI:206101) (RXCUI:206101)                                   44
# Estradiol 1 MG Oral Tablet [Estrace] RXCUI:206101 (RXCUI:206101)                                     44
# 010 Positive/elevated                                                                                41
# Estradiol 0.025 MG Vaginal Tablet (Vagifem) (RXCUI:284412) (RXCUI:284412)                            32
# Estrogens, Conjugated (USP) 0.9 MG Oral Tablet (Premarin) (RXCUI:208949) (RXCUI:208949)              31
# Estrogens, Conjugated (USP) 0.9 MG Oral Tablet [Premarin] RXCUI:208949 (RXCUI:208949)                31
# Hepatitis C virus genotype, PCR (Polymerase Chain Reaction) (HDID:11705)                             28
# day of cycle (HDID:39874)                                                                            28
# Estradiol 2 MG Oral Tablet (Estrace) (RXCUI:206241) (RXCUI:206241)                                   27
# estrogens, conjugated synthetic A 1.25 MG Oral Tablet (Cenestin) (RXCUI:261371) (RXCUI:261371)        1
# Estrogens, Esterified (USP) 0.3 MG Oral Tablet [Menest] RXCUI:212039 (RXCUI:212039)                   1
# Estradiol 5 MG/ML Injectable Solution (Depo-estradiol) (RXCUI:206417) (RXCUI:206417)                  1
# Name: NAME_CHAR, Length: 88, dtype: int64

# %% [markdown]
# # how many RXCUI
# #### "RxNorm concept unique identifier (RXCUI): This RXCUI always designates the same concept, no matter the form of the name and no matter in what table it is found. Drugs whose names map to the same RXCUI are taken to be the same drug - identical as to ingredients, strengths, and dose forms. Conversely, drugs that differ in any of these particulars are conceptually distinct and will have different RXCUIs.
# #### Clinical drug component RXCUI: An RxNorm concept unique identifier for a clinical drug. A clinical drug is a pharmaceutical product given to (or taken by) a patient with a therapeutic or diagnostic intent. In RxNorm, the name of a clinical drug combines its ingredients, strengths, and/or form."

# %%
df_RXCUI=df2[df2['NAME_CHAR'].str.contains("RXCUI")]
df_RXCUI.NAME_CHAR.value_counts()
# Out:
# Estrogens, Conjugated (USP) 0.625 MG/ML Vaginal Cream [Premarin] RXCUI:688242 (RXCUI:688242)       4168
# Estrogens, Conjugated (USP) 0.625 MG/ML Vaginal Cream (Premarin) (RXCUI:688242) (RXCUI:688242)     4168
# Estradiol 0.1 MG/ML Vaginal Cream [Estrace] RXCUI:890918 (RXCUI:890918)                             790
# Estrogens, Conjugated (USP) 0.625 MG Oral Tablet [Premarin] RXCUI:150840 (RXCUI:150840)             507
# Estrogens, Conjugated (USP) 0.625 MG Oral Tablet (Premarin) (RXCUI:150840) (RXCUI:150840)           507
# Estrogens, Conjugated (USP) 0.3 MG Oral Tablet (Premarin) (RXCUI:208513) (RXCUI:208513)             180
# Estrogens, Conjugated (USP) 0.3 MG Oral Tablet [Premarin] RXCUI:208513 (RXCUI:208513)               180
# 90 DAY Estradiol 0.000313 MG/HR Vaginal Ring (Estring) (RXCUI:848330) (RXCUI:848330)                172
# Estrogens, Conjugated (USP) 1.25 MG Oral Tablet [Premarin] RXCUI:202301 (RXCUI:202301)               56
# Estrogens, Conjugated (USP) 1.25 MG Oral Tablet (Premarin) (RXCUI:202301) (RXCUI:202301)             56
# Estradiol 1 MG Oral Tablet [Estrace] RXCUI:206101 (RXCUI:206101)                                     44
# Estradiol 1 MG Oral Tablet (Estrace) (RXCUI:206101) (RXCUI:206101)                                   44
# Estradiol 0.025 MG Vaginal Tablet (Vagifem) (RXCUI:284412) (RXCUI:284412)                            32
# Estrogens, Conjugated (USP) 0.9 MG Oral Tablet [Premarin] RXCUI:208949 (RXCUI:208949)                31
# Estrogens, Conjugated (USP) 0.9 MG Oral Tablet (Premarin) (RXCUI:208949) (RXCUI:208949)              31
# Estradiol 2 MG Oral Tablet (Estrace) (RXCUI:206241) (RXCUI:206241)                                   27
# Estradiol 1 MG Oral Tablet (RXCUI:197658) (RXCUI:197658)                                             27
# Estrogens, Conjugated (USP) 2.5 MG Oral Tablet (Premarin) (RXCUI:202302) (RXCUI:202302)               2
# 168 HR Estradiol 0.00417 MG/HR Transdermal Patch (Climara) (RXCUI:310181) (RXCUI:310181)              2
# 84 HR Estradiol 0.00417 MG/HR Transdermal Patch (Vivelle) (RXCUI:310183) (RXCUI:310183)               1
# Estrogens, Esterified (USP) 0.3 MG Oral Tablet (Menest) (RXCUI:212039) (RXCUI:212039)                 1
# 168 HR Estradiol 0.00312 MG/HR Transdermal Patch RXCUI:241527 (RXCUI:241527)                          1
# estrogens, conjugated synthetic A 0.625 MG Oral Tablet (Cenestin) (RXCUI:261220) (RXCUI:261220)       1
# Estradiol 5 MG/ML Injectable Solution (Depo-estradiol) (RXCUI:206417) (RXCUI:206417)                  1
# estrogens, conjugated synthetic A 0.625 MG Oral Tablet [Cenestin] RXCUI:261220 (RXCUI:261220)         1
# estrogens, conjugated synthetic A 1.25 MG Oral Tablet (Cenestin) (RXCUI:261371) (RXCUI:261371)        1
# 168 HR Estradiol 0.00312 MG/HR Transdermal Patch (Climara) (RXCUI:310178) (RXCUI:310178)              1
# 84 HR Estradiol 0.00208 MG/HR Transdermal Patch (Alora) (RXCUI:310173) (RXCUI:310173)                 1
# Estrogens, Esterified (USP) 0.3 MG Oral Tablet [Menest] RXCUI:212039 (RXCUI:212039)                   1
# 168 HR Estradiol 0.00312 MG/HR Transdermal Patch (RXCUI:241527) (RXCUI:241527)                        1
# Premarin RXCUI:202896 (RXCUI:202896)                                                                  1
# 84 HR Estradiol 0.00104 MG/HR Transdermal Patch (Vivelle) (RXCUI:284378) (RXCUI:284378)               1
# Name: NAME_CHAR, Length: 66, dtype: int64

# %% [markdown]
# # how many unique patients have RXCUI

# %%
len(df_RXCUI.PATIENT_NUM.unique())
# Out:
# 2007

# %%
#df_RXCUI.PATIENT_NUM.value_counts()

# %% [markdown]
# ##  all high freq features by value_counts of column CONCEPT_PATH

# %%
df2.CONCEPT_PATH.value_counts()#.to_dict()
#df2.concept_path.value_counts()
# Out:
# \Drug Products by VA Class\GU000 GENITOURINARY MEDICATIONS\GU500 ESTROGENS,VAGINAL\378764\688242\                                                                 8336
# \Drug Products by VA Class\HS000 HORMONES/SYNTHETICS/MODIFIERS\HS300 ESTROGENS\378834\150840\                                                                     1014
# \Drug Products by VA Class\GU000 GENITOURINARY MEDICATIONS\GU500 ESTROGENS,VAGINAL\378615\890918\                                                                  790
# \HDID2\Basic\Dx\Lab\Chemistry\follicle stimulating hormone, serum (HDID:149)\                                                                                      501
# \HDID\GE-F\follicle stimulating hormone, serum (HDID:149)\                                                                                                         501
# \Drug Products by VA Class\HS000 HORMONES/SYNTHETICS/MODIFIERS\HS300 ESTROGENS\378834\208513\                                                                      360
# \HDID\GE-L\luteinizing hormone, serum (HDID:301)\                                                                                                                  264
# \HDID2\Basic\Dx\Lab\Chemistry\luteinizing hormone, serum (HDID:301)\                                                                                               264
# \Drug Products by VA Class\HS000 HORMONES/SYNTHETICS/MODIFIERS\HS300 ESTROGENS\848327\848330\                                                                      172
# \HDID2\Basic\Hx\PMH\infertility, hx of (HDID:7177)\                                                                                                                124
# \HDID\GE-I\infertility, hx of (HDID:7177)\                                                                                                                         124
# \Drug Products by VA Class\HS000 HORMONES/SYNTHETICS/MODIFIERS\HS300 ESTROGENS\378834\202301\                                                                      112
# \Drug Products by VA Class\HS000 HORMONES/SYNTHETICS/MODIFIERS\HS300 ESTROGENS\372078\206101\                                                                       88
# \Drug Products by VA Class\HS000 HORMONES/SYNTHETICS/MODIFIERS\HS300 ESTROGENS
# \Drug Products by VA Class\HS000 HORMONES/SYNTHETICS/MODIFIERS\HS300 ESTROGENS\284732\310173\                                                                        1
# \HDID2\Basic\Dx\Lab\Genetics/fertility\Neisseria Gonorrhoeae DNA (TMA) result (HDID:46359)\                                                                          1
# \Drug Products by VA Class\HS000 HORMONES/SYNTHETICS/MODIFIERS\HS300 ESTROGENS\284732\310183\                                                                        1
# \Drug Products by VA Class\HS000 HORMONES/SYNTHETICS/MODIFIERS\HS300 ESTROGENS\284732\284378\                                                                        1
# \Drug Products by VA Class\GU000 GENITOURINARY MEDICATIONS\GU500 ESTROGENS,VAGINAL\378764\202896\                                                                    1
# Name: CONCEPT_PATH, Length: 81, dtype: int64

# %%
df2.CONCEPT_CD.value_counts()
# Out:
# RXCUI:688242          8336
# RXCUI:150840          1014
# HDID:149              1002
# RXCUI:890918           790
# HDID:301               528
# RXCUI:208513           360
# HDID:7177              248
# RXCUI:848330           172
# RXCUI:202301           112
# RXCUI:206101            88
# RXCUI:208949            62
# ICD9:628.9              56
# RXCUI:206241            54
# RXCUI:197658            54
# HDID:292                48
# RXCUI:284412            32
# HDID:39874              28
# HDID:11705              28
# RXCUI:404550            26
# RXCUI:197659            24
# RXCUI:310175            23
# HDID:50588              22
# RXCUI:310170            22
# RXCUI:310174            21
# NAACCR|13:2880:010      21
# NAACCR|13:2890:010      20
# RXCUI:884709            20
# RXCUI:206620            19
# RXCUI:205909            16
# HDID:3232               14
#                       ...
# HDID:21762               4
# RXCUI:581549             4
# RXCUI:831872             3
# RXCUI:310182             3
# HDID:137251              3
# HDID:29018               3
# RXCUI:404656             3
# ICD9:628.0               3
# RXCUI:212232             3
# RXCUI:206715             2
# ICD9:628.3               2
# RXCUI:310190             2
# RXCUI:214049             2
# ICD9:256.0               2
# RXCUI:241527             2
# RXCUI:310181             2
# RXCUI:261220             2
# RXCUI:202302             2
# RXCUI:212039             2
# RXCUI:310173             1
# RXCUI:284378             1
# RXCUI:206417             1
# RXCUI:310183             1
# RXCUI:202896             1
# HDID:6707                1
# NAACCR|13:2880:998       1
# RXCUI:261371             1
# RXCUI:310178             1
# NAACCR|13:2890:998       1
# HDID:46359               1
# Name: CONCEPT_CD, Length: 75, dtype: int64

# %%
df_RXCUI=df2[df2['NAME_CHAR'].str.contains("RXCUI")]
df_RXCUI.NAME_CHAR.value_counts()
len(df_RXCUI.PATIENT_NUM.unique())
# Out:
# 2007

# %% [markdown]
# ## most patients have 1 obs but some have dozens

# %%
df_RXCUI.PATIENT_NUM.value_counts()
# Out:
# 1219988    55
# 1634311    54
# 3136000    53
# 1411942    49
# 957999     44
# 1119118    44
# 4626097    41
# 1414791    40
# 1392587    40
# 1097054    40
# 3098067    39
# 866649     38
# 1087779    38
# 1085609    38
# 2342011    36
# 1209271    36
# 3459946    36
# 1786435    36
# 1239546    36
# 2361898    35
# 1270031    34
# 39361      34
# 4413619    33
# 3024910    33
# 1497818    32
# 1123633    32
# 1794982    32
# 403683     31
# 1291801    31
# 1485071    30
#            ..
# 1396444     2
# 499646      2
# 1345820     2
# 2229724     2
# 655074      2
# 5679247     2
# 4404995     2
# 1193787     2
# 2514750     2
# 5408746     2
# 4759398     2
# 3248091     2
# 2672586     2
# 5883773     2
# 2887556     2
# 5179314     2
# 1619884     2
# 1380267     2
# 4822944     2
# 5271455     2
# 4046749     2
# 1257368     2
# 2705325     2
# 4058999     2
# 1353590     2
# 3680110     2
# 8746836     2
# 9283505     2
# 6324332     2
# 1153838     1
# Name: PATIENT_NUM, Length: 2007, dtype: int64

# %% [markdown]
# ## why some patients have more obs

# %% [markdown]
# # patient with RXCUI

# %%
#1713971     
df1234674=df2[df2.PATIENT_NUM==1713971]
df1234674.sort_values(['START_DATE'])
# Out:
#       PATIENT_NUM    CONCEPT_CD          START_DATE VALTYPE_CD  \
# 8027      1713971  RXCUI:310176 2001-07-20 10:01:37        NaN
# 8026      1713971  RXCUI:310176 2001-07-20 10:01:37        NaN
# 8025      1713971  RXCUI:310176 2002-05-31 13:04:18        NaN
# 8024      1713971  RXCUI:310176 2002-05-31 13:04:18        NaN
# 8021      1713971  RXCUI:688242 2002-08-27 15:43:59        NaN
# 8020      1713971  RXCUI:688242 2002-08-27 15:43:59        NaN
# 8010      1713971  RXCUI:284412 2003-12-13 13:08:56        NaN
# 8019      1713971  RXCUI:848330 2003-12-13 13:08:56        NaN
# 8008      1713971  RXCUI:688242 2004-12-28 15:19:29        NaN
# 8009      1713971  RXCUI:688242 2004-12-28 15:19:29        NaN
# 8015      1713971  RXCUI:284412 2005-07-05 17:06:07        NaN
# 8018      1713971  RXCUI:848330 2006-03-21 14:36:16        NaN
# 8014      1713971  RXCUI:284412 2006-03-21 14:36:16        NaN
# 8013      1713971  RXCUI:284412 2007-02-28 15:14:22        NaN
# 8012      1713971  RXCUI:284412 2008-04-23 15:28:51        NaN
# 8022      1713971  RXCUI:688242 2008-04-23 15:28:51        NaN
# 8023      1713971  RXCUI:688242 2008-04-23 15:28:51        NaN
# 8011      1713971  RXCUI:284412 2008-11-12 13:18:40        NaN
# 8016      1713971    HDID:50588 2008-11-27 15:07:39          T
# 8017      1713971    HDID:50588 2008-11-27 15:07:39          T
#
#                                               TVAL_CHAR  NVAL_NUM  \
# 8027                                change twice a week       NaN
# 8026                                change twice a week       NaN
# 8025                          apply  patch twice a week       NaN
# 8024                          apply  patch twice a week       NaN
# 8021  use one half applicator twice a week in the va...       NaN
# 8020  use one half applicator twice a week in the va...       NaN
# 8010               place one tab in vagina twice a week       NaN
# 8019        insert in vagina, wear for 90 days, replace       NaN
# 8008  one gram intravaginal daily for 7 days, then t...       NaN
# 8009  one gram intravaginal daily for 7 days, then t...       NaN
# 8015                                   use twice a week       NaN
# 8018        insert in vagina, wear for 90 days, replace       NaN
# 8014               place one tab in vagina twice a week       NaN
# 8013               place one tab in vagina twice a week       NaN
# 8012               place one tab in vagina twice a week       NaN
# 8022  use one half applicator twice a week in the va...       NaN
# 8023  use one half applicator twice a week in the va...       NaN
# 8011               place one tab in vagina twice a week       NaN
# 8016                                                Neg       NaN
# 8017                                                Neg       NaN
#
#                                            CONCEPT_PATH  \
# 8027  \Drug Products by VA Class\HS000 HORMONES/SYNT...
# 8026  \Drug Products by VA Class\HS000 HORMONES/SYNT...
# 8025  \Drug Products by VA Class\HS000 HORMONES/SYNT...
# 8024  \Drug Products by VA Class\HS000 HORMONES/SYNT...
# 8021  \Drug Products by VA Class\GU000 GENITOURINARY...
# 8020  \Drug Products by VA Class\GU000 GENITOURINARY...
# 8010  \Drug Products by VA Class\GU000 GENITOURINARY...
# 8019  \Drug Products by VA Class\HS000 HORMONES/SYNT...
# 8008  \Drug Products by VA Class\GU000 GENITOURINARY...
# 8009  \Drug Products by VA Class\GU000 GENITOURINARY...
# 8015  \Drug Products by VA Class\GU000 GENITOURINARY...
# 8018  \Drug Products by VA Class\HS000 HORMONES/SYNT...
# 8014  \Drug Products by VA Class\GU000 GENITOURINARY...
# 8013  \Drug Products by VA Class\GU000 GENITOURINARY...
# 8012  \Drug Products by VA Class\GU000 GENITOURINARY...
# 8022  \Drug Products by VA Class\GU000 GENITOURINARY...
# 8023  \Drug Products by VA Class\GU000 GENITOURINARY...
# 8011  \Drug Products by VA Class\GU000 GENITOURINARY...
# 8016  \HDID2\Basic\Dx\Lab\Genetics/fertility\pregnan...
# 8017    \HDID\GE-P\pregnancy test results (HDID:50588)\
#
#                                               NAME_CHAR SEX_CD  \
# 8027  84 HR Estradiol 0.00208 MG/HR Transdermal Patc...      F
# 8026  84 HR Estradiol 0.00208 MG/HR Transdermal Patc...      F
# 8025  84 HR Estradiol 0.00208 MG/HR Transdermal Patc...      F
# 8024  84 HR Estradiol 0.00208 MG/HR Transdermal Patc...      F
# 8021  Estrogens, Conjugated (USP) 0.625 MG/ML Vagina...      F
# 8020  Estrogens, Conjugated (USP) 0.625 MG/ML Vagina...      F
# 8010  Estradiol 0.025 MG Vaginal Tablet (Vagifem) (R...      F
# 8019  90 DAY Estradiol 0.000313 MG/HR Vaginal Ring (...      F
# 8008  Estrogens, Conjugated (USP) 0.625 MG/ML Vagina...      F
# 8009  Estrogens, Conjugated (USP) 0.625 MG/ML Vagina...      F
# 8015  Estradiol 0.025 MG Vaginal Tablet (Vagifem) (R...      F
# 8018  90 DAY Estradiol 0.000313 MG/HR Vaginal Ring (...      F
# 8014  Estradiol 0.025 MG Vaginal Tablet (Vagifem) (R...      F
# 8013  Estradiol 0.025 MG Vaginal Tablet (Vagifem) (R...      F
# 8012  Estradiol 0.025 MG Vaginal Tablet (Vagifem) (R...      F
# 8022  Estrogens, Conjugated (USP) 0.625 MG/ML Vagina...      F
# 8023  Estrogens, Conjugated (USP) 0.625 MG/ML Vagina...      F
# 8011  Estradiol 0.025 MG Vaginal Tablet (Vagifem) (R...      F
# 8016                pregnancy test results (HDID:50588)      F
# 8017                pregnancy test results (HDID:50588)      F
#
#             LANGUAGE_CD     RACE_CD ZIP_CD
# 8027  DEM|LANGUAGE:engl  DEM|RACE:c   2138
# 8026  DEM|LANGUAGE:engl  DEM|RACE:c   2138
# 8025  DEM|LANGUAGE:engl  DEM|RACE:c   2138
# 8024  DEM|LANGUAGE:engl  DEM|RACE:c   2138
# 8021  DEM|LANGUAGE:engl  DEM|RACE:c   2138
# 8020  DEM|LANGUAGE:engl  DEM|RACE:c   2138
# 8010  DEM|LANGUAGE:engl  DEM|RACE:c   2138
# 8019  DEM|LANGUAGE:engl  DEM|RACE:c   2138
# 8008  DEM|LANGUAGE:engl  DEM|RACE:c   2138
# 8009  DEM|LANGUAGE:engl  DEM|RACE:c   2138
# 8015  DEM|LANGUAGE:engl  DEM|RACE:c   2138
# 8018  DEM|LANGUAGE:engl  DEM|RACE:c   2138
# 8014  DEM|LANGUAGE:engl  DEM|RACE:c   2138
# 8013  DEM|LANGUAGE:engl  DEM|RACE:c   2138
# 8012  DEM|LANGUAGE:engl  DEM|RACE:c   2138
# 8022  DEM|LANGUAGE:engl  DEM|RACE:c   2138
# 8023  DEM|LANGUAGE:engl  DEM|RACE:c   2138
# 8011  DEM|LANGUAGE:engl  DEM|RACE:c   2138
# 8016  DEM|LANGUAGE:engl  DEM|RACE:c   2138
# 8017  DEM|LANGUAGE:engl  DEM|RACE:c   2138

# %% [markdown]
# # patient without RXCUI

# %%
df4967361=df2[df2.PATIENT_NUM==4967361]

df4967361.sort_values(['START_DATE'])
# Out:
# Empty DataFrame
# Columns: [PATIENT_NUM, CONCEPT_CD, START_DATE, VALTYPE_CD, TVAL_CHAR, NVAL_NUM, CONCEPT_PATH, NAME_CHAR, SEX_CD, LANGUAGE_CD, RACE_CD, ZIP_CD]
# Index: []

# %%
df2[df2.PATIENT_NUM==4967361].NAME_CHAR.value_counts()
# Out:
# Series([], Name: NAME_CHAR, dtype: int64)

# %%
df9275896=df2[df2.PATIENT_NUM==9275896]
df9275896
# Out:
# Empty DataFrame
# Columns: [PATIENT_NUM, CONCEPT_CD, START_DATE, VALTYPE_CD, TVAL_CHAR, NVAL_NUM, CONCEPT_PATH, NAME_CHAR, SEX_CD, LANGUAGE_CD, RACE_CD, ZIP_CD]
# Index: []
